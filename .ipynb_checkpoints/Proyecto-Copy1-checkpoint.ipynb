# %% [markdown]
# # Proyecto de Grado - Ciencia de Datos
# # Universidad Libre Cali
# ## Leiner Samir Rodriguez Velasco
# ## Miguel Angel Zapata Rubiano

# %% [markdown]
# #### IMPORTAMOS LAS LIBRERIAS QUE VAMOS A UTILIZAR

# %%
# import libraries 
import pandas as pd # Import Pandas for data manipulation using dataframes
import numpy as np # Import Numpy for data statistical analysis 
import matplotlib.pyplot as plt # Import matplotlib for data visualisation
from matplotlib import pyplot as plt
import seaborn as sns # Statistical data visualization
import os
import datetime as dt
# %matplotlib inline

# %% [markdown]
# #### SE HACE EL LLAMADO A LAS BASES DE DATOS A USAR

# %%
datos = pd.read_excel('C:/Users/migue/anaconda3/content/PROYECTO/datos.xlsx')

# %%
datos.head()
# Out:
#        fecha        mes   año    canal  id_pais       pais  id_negocio  \
# 0 2020-11-01  Noviembre  2020  New_APP        1  ARGENTINA           0
# 1 2020-11-01  Noviembre  2020  New_APP        1  ARGENTINA           1
# 2 2020-11-01  Noviembre  2020  New_APP        1  ARGENTINA           0
# 3 2020-11-01  Noviembre  2020  New_APP        1  ARGENTINA           1
# 4 2020-11-01  Noviembre  2020  New_APP        1  ARGENTINA           0
#
#   negocio         estado_sms             error                    solucion  \
# 0     POS  Procesado-Exitoso  Cambiar Password          asistencia_tecnica
# 1     PRE  Procesado-Exitoso  Cambiar Password           reset_de_password
# 2     POS  Procesado-Exitoso  Cambiar Password  validacion_de_credenciales
# 3     PRE  Procesado-Exitoso  Cambiar Password  validacion_de_credenciales
# 4     POS  Procesado-Exitoso  Cambiar Password          asistencia_tecnica
#
#   estado  cantidad
# 0    Yes      71.0
# 1    Yes      51.0
# 2    Yes      10.0
# 3    Yes      15.0
# 4    Yes      37.0

# %%
paises = pd.read_excel('C:/Users/migue/anaconda3/content/PROYECTO/paises.xlsx')

# %%
paises.head()
# Out:
#    pais_id       pais        latitud   longitud                coordenadas
# 0        1  ARGENTINA  -81.6426644,4 -37.054444  -37.0544439,-81.6426644,4
# 1        2      CHILE  -106.252478,4 -35.441628  -35.4416283,-106.252478,4
# 2        3   COLOMBIA  -83.3895534,5   4.587759    4.5877586,-83.3895534,5
# 3        4    ECUADOR  -88.3954577,6  -1.355238   -1.3552379,-88.3954577,6
# 4        5       PERU  -84.0673974,5  -9.130473   -9.1304727,-84.0673974,5

# %% [markdown]
# #### SE COMPRUEBAN LOS NOMBRES DE LAS COLUMNAS QUE HACEN PARTE DE LAS BASES DE DATOS

# %%
datos.columns
# Out:
# Index(['fecha', 'mes', 'año', 'canal', 'id_pais', 'pais', 'id_negocio',
#        'negocio', 'estado_sms', 'error', 'solucion', 'estado', 'cantidad'],
#       dtype='object')

# %%
paises.columns
# Out:
# Index(['pais_id', 'pais', 'latitud', 'longitud', 'coordenadas'], dtype='object')

# %% [markdown]
# #### SE REALIZA LA COMPROBACION DE LOS DATOS POR NEGOCIO

# %%
total = datos.loc[datos['negocio'] == 'POS', 'cantidad'].sum()

# %%
print(total)
# Out:
# 1275312.4544402468

# %%
total = datos.loc[datos['negocio'] == 'PRE', 'cantidad'].sum()

# %%
print(total)
# Out:
# 735587.1715748464

# %% [markdown]
# #### SE HACE LA RESPECTIVA UNION DE LAS BASES DE DATOS (EN ESTE CASO SE HARA LA UNION POR EL ID DEL PAIS)

# %%
union = pd.merge(left=datos,right=paises, left_on='id_pais', right_on='pais_id')

# %%
union.shape
union
# Out:
#            fecha        mes   año    canal  id_pais     pais_x  id_negocio  \
# 0     2020-11-01  Noviembre  2020  New_APP        1  ARGENTINA           0
# 1     2020-11-01  Noviembre  2020  New_APP        1  ARGENTINA           1
# 2     2020-11-01  Noviembre  2020  New_APP        1  ARGENTINA           0
# 3     2020-11-01  Noviembre  2020  New_APP        1  ARGENTINA           1
# 4     2020-11-01  Noviembre  2020  New_APP        1  ARGENTINA           0
# ...          ...        ...   ...      ...      ...        ...         ...
# 25884 2021-04-22      Abril  2021      WEB        6    URUGUAY           0
# 25885 2021-04-23      Abril  2021      WEB        6    URUGUAY           1
# 25886 2021-04-24      Abril  2021      WEB        6    URUGUAY           0
# 25887 2021-04-25      Abril  2021      WEB        6    URUGUAY           1
# 25888 2021-04-26      Abril  2021      WEB        6    URUGUAY           0
#
#       negocio         estado_sms             error  \
# 0         POS  Procesado-Exitoso  Cambiar Password
# 1         PRE  Procesado-Exitoso  Cambiar Password
# 2         POS  Procesado-Exitoso  Cambiar Password
# 3         PRE  Procesado-Exitoso  Cambiar Password
# 4         POS  Procesado-Exitoso  Cambiar Password
# ...       ...                ...               ...
# 25884     POS  Procesado-Exitoso     FALLO_TECNICO
# 25885     PRE  Procesado-Exitoso     FALLO_TECNICO
# 25886     POS  Procesado-Exitoso     FALLO_TECNICO
# 25887     PRE  Procesado-Exitoso     FALLO_TECNICO
# 25888     POS  Procesado-Exitoso     FALLO_TECNICO
#
#                            solucion estado  cantidad  pais_id     pais_y  \
# 0                asistencia_tecnica    Yes      71.0        1  ARGENTINA
# 1                 reset_de_password    Yes      51.0        1  ARGENTINA
# 2        validacion_de_credenciales    Yes      10.0        1  ARGENTINA
# 3        validacion_de_credenciales    Yes      15.0        1  ARGENTINA
# 4                asistencia_tecnica    Yes      37.0        1  ARGENTINA
# ...                             ...    ...       ...      ...        ...
# 25884            asistencia_tecnica    Yes       1.0        6    URUGUAY
# 25885  validacion_estado_del_equipo    Yes       1.0        6    URUGUAY
# 25886  validacion_estado_del_equipo    Yes       1.0        6    URUGUAY
# 25887            asistencia_tecnica    Yes       1.0        6    URUGUAY
# 25888            asistencia_tecnica    Yes       1.0        6    URUGUAY
#
#              latitud   longitud                coordenadas
# 0      -81.6426644,4 -37.054444  -37.0544439,-81.6426644,4
# 1      -81.6426644,4 -37.054444  -37.0544439,-81.6426644,4
# 2      -81.6426644,4 -37.054444  -37.0544439,-81.6426644,4
# 3      -81.6426644,4 -37.054444  -37.0544439,-81.6426644,4
# 4      -81.6426644,4 -37.054444  -37.0544439,-81.6426644,4
# ...              ...        ...                        ...
# 25884  -58.0284717,7 -32.600557  -32.6005567,-58.0284717,7
# 25885  -58.0284717,7 -32.600557  -32.6005567,-58.0284717,7
# 25886  -58.0284717,7 -32.600557  -32.6005567,-58.0284717,7
# 25887  -58.0284717,7 -32.600557  -32.6005567,-58.0284717,7
# 25888  -58.0284717,7 -32.600557  -32.6005567,-58.0284717,7
#
# [25889 rows x 18 columns]

# %%
df = pd.DataFrame(union)

# %% [markdown]
# #### SE HACE LA COMPROBACION DE LOS DATOS DE LA COLUMNA CANTIDAD PARA LOS NEGOCIOS PRE Y POS PARA COMPROBAR SI LA UNION D ELAS BASES DE DATOS NO AFECTARA LOS DATOS YA EXISTENTES

# %%
total = union.loc[union['negocio'] == 'POS', 'cantidad'].sum()

# %%
print(total)
# Out:
# 1275312.4544402466

# %%
total = union.loc[union['negocio'] == 'PRE', 'cantidad'].sum()

# %%
print(total)
# Out:
# 735587.1715748464

# %% [markdown]
# #### SE VUELVE A HACER LA COMPROBACION DE LOS NOMBRES DE LAS COLUMNAS LUEGO DE HABER HECHO LA UNION DE BASES DE DATOS

# %%
union.columns
# Out:
# Index(['fecha', 'mes', 'año', 'canal', 'id_pais', 'pais_x', 'id_negocio',
#        'negocio', 'estado_sms', 'error', 'solucion', 'estado', 'cantidad',
#        'pais_id', 'pais_y', 'latitud', 'longitud', 'coordenadas'],
#       dtype='object')

# %% [markdown]
# #### SE COMPRUEBA SI EN LA UNION DE LOS DATOS NO QUEDAN DATOS NULOS

# %%
print(union.info())
print(union.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25889 entries, 0 to 25888
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   fecha        25889 non-null  datetime64[ns]
#  1   mes          25889 non-null  object
#  2   año          25889 non-null  int64
#  3   canal        25889 non-null  object
#  4   id_pais      25889 non-null  int64
#  5   pais_x       25889 non-null  object
#  6   id_negocio   25889 non-null  int64
#  7   negocio      25889 non-null  object
#  8   estado_sms   25889 non-null  object
#  9   error        25889 non-null  object
#  10  solucion     25889 non-null  object
#  11  estado       25889 non-null  object
#  12  cantidad     25889 non-null  float64
#  13  pais_id      25889 non-null  int64
#  14  pais_y       25889 non-null  object
#  15  latitud      25889 non-null  object
#  16  longitud     25889 non-null  float64
#  17  coordenadas  25889 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(4), object(11)
# memory usage: 3.8+ MB
# None
# fecha          0
# mes            0
# año            0
# canal          0
# id_pais        0
# pais_x         0
# id_negocio     0
# negocio        0
# estado_sms     0
# error          0
# solucion       0
# estado         0
# cantidad       0
# pais_id        0
# pais_y         0
# latitud        0
# longitud       0
# coordenadas    0
# dtype: int64

# %% [markdown]
# #### SE COMPRUEBAN LOS DATOS QUE HAY POR COLUMNAS

# %%
union['pais_x']
# Out:
# 0        ARGENTINA
# 1        ARGENTINA
# 2        ARGENTINA
# 3        ARGENTINA
# 4        ARGENTINA
#            ...
# 25884      URUGUAY
# 25885      URUGUAY
# 25886      URUGUAY
# 25887      URUGUAY
# 25888      URUGUAY
# Name: pais_x, Length: 25889, dtype: object

# %%
pd.unique(union['pais_x'])
# Out:
# array(['ARGENTINA', 'ECUADOR', 'CHILE', 'COLOMBIA', 'PERU', 'URUGUAY'],
#       dtype=object)

# %%
union['estado_sms']
# Out:
# 0        Procesado-Exitoso
# 1        Procesado-Exitoso
# 2        Procesado-Exitoso
# 3        Procesado-Exitoso
# 4        Procesado-Exitoso
#                ...
# 25884    Procesado-Exitoso
# 25885    Procesado-Exitoso
# 25886    Procesado-Exitoso
# 25887    Procesado-Exitoso
# 25888    Procesado-Exitoso
# Name: estado_sms, Length: 25889, dtype: object

# %%
pd.unique(union['estado_sms'])
# Out:
# array(['Procesado-Exitoso', 'FINALIZADO', 'Procesado-No-Exitoso'],
#       dtype=object)

# %%
union['error']
# Out:
# 0        Cambiar Password
# 1        Cambiar Password
# 2        Cambiar Password
# 3        Cambiar Password
# 4        Cambiar Password
#                ...
# 25884       FALLO_TECNICO
# 25885       FALLO_TECNICO
# 25886       FALLO_TECNICO
# 25887       FALLO_TECNICO
# 25888       FALLO_TECNICO
# Name: error, Length: 25889, dtype: object

# %%
pd.unique(union['error'])
# Out:
# array(['Cambiar Password', 'Mensaje Error En Pantalla', 'Error Pago',
#        'FALLO_TECNICO', 'BAJA SERVICIO'], dtype=object)

# %%
union['solucion']
# Out:
# 0                  asistencia_tecnica
# 1                   reset_de_password
# 2          validacion_de_credenciales
# 3          validacion_de_credenciales
# 4                  asistencia_tecnica
#                      ...
# 25884              asistencia_tecnica
# 25885    validacion_estado_del_equipo
# 25886    validacion_estado_del_equipo
# 25887              asistencia_tecnica
# 25888              asistencia_tecnica
# Name: solucion, Length: 25889, dtype: object

# %%
pd.unique(union['solucion'])
# Out:
# array(['asistencia_tecnica', 'reset_de_password',
#        'validacion_de_credenciales', 'cambio_de_tarjeta',
#        'validacion_estado_del_equipo', 'acuerdo_de_pago', 'refacturacion',
#        'pago_de_saldo_en_mora', 'cambio_de_equipo',
#        'modificacion_de_servicios', 'cancelacion_de_servicios',
#        'acreditacion_de_pago'], dtype=object)

# %% [markdown]
# #### HACEMOS UN MAPA PARA PODER DEFINIR LAS RELACIONES DE LAS VARIABLES

# %%
g = sns.pairplot(union)

# %% [markdown]
# #### DEMOSTRAMOS LA CANTIDAD DE CADA NEGOCIO PARA SABER CUAL NEGOCIO ES EL QUE PRESENTA MAS FALLOS

# %%
sns.countplot(x='negocio', data= union)
 
# Show the plot
plt.show()

# %% [markdown]
# #### Cantidad de errores por negocio

# %%
sb.factorplot('error',data=datos,hue='id_negocio',kind="count")
# Out:
# C:\Users\migue\anaconda3\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\migue\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### REPRESENTAMOS LOS NEGOCIOS POR MES

# %%
ax = sns.countplot(x="mes", hue="negocio", data=union)

# %% [markdown]
# #### Cantidad de datos por pais

# %%
sb.factorplot('pais',data=datos,kind="count", aspect=3)
# Out:
# C:\Users\migue\anaconda3\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\migue\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### HACEMOS LA REPRESENTACION DE PAISES POR MES Y SU CANTIDAD

# %%
plt.figure(figsize=(20,10))
ax = sns.countplot(x="mes", hue="pais_x", data=union)
plt.show()

# %% [markdown]
# #### REPRESENTAMOS LA CANTIDAD DEL ESTADO A LOS ERRORES PRESENTADOS

# %%
ax = sns.countplot(y="estado_sms", data=union)

# %% [markdown]
# #### DEMOSTRAMOS CUAL ES EL CANAL POR EL CUAL LOS CLIENTE MANIFIESTAN LOS ERRORES ENCONTRADOS A LA EMPRESA

# %%
plt.figure(figsize=(7,5)) 
sns.countplot(x='canal', data= union)
plt.show()

# %% [markdown]
# #### SE HACE LA REPRESENTACION DEL ERROR MAS FRECUENTE MANIFESTADO POR EL CLIENTE

# %%
plt.figure(figsize=(13,9))
sns.countplot(y='error', data= union)
 
# Show the plot
plt.show()

# %% [markdown]
# #### SE REPRESENTA CUAL ES LA SOLUCION MAS FRECUENTE PROPORCIONADA POR LA EMPRESA

# %%
plt.figure(figsize=(15,9))
sns.countplot(y='solucion', data= union)
 
# Show the plot
plt.show()

# %% [markdown]
# #### SE REPRESENTA POR PAIS CUAL ES EL ERROR MAS FRECUENTE MANIFESTADO POR EL CLIENTE

# %%
plt.figure(figsize=(20,10))
ax = sns.countplot(x="pais_x", hue="error", data=union)
plt.show()

# %% [markdown]
# #### SE REPRENTA POR PAIS LA SOLUCION MAS FRECUENTE PROPORCIONADA POR LA EMPRESA

# %%
plt.figure(figsize=(20,10))
ax = sns.countplot(x="pais_x", hue="solucion", data=union)
plt.show()

# %% [markdown]
# #### SE HACE LA REPRESENTACION DE LOS ERRORES MANIFECTADOS POR LOS CLIENTES Y LA SOLUCION QUE PROPORCIONA LA EMPRESA

# %%
plt.figure(figsize=(15,8))
ax = sns.countplot(x="error", hue="solucion", data=union)
plt.show()

# %% [markdown]
# #### Comportamientos Mensuales

# %%
# Librerias
from datetime import datetime, timedelta
from matplotlib import dates as mpl_dates

# %%
print("Fecha inicial", union['fecha'].min())
print("Fecha final", union['fecha'].max())
print("Cantidad de dias", union['fecha'].max() - union['fecha'].min() )
# Out:
# Fecha inicial 2020-11-01 00:00:00
# Fecha final 2021-04-30 00:00:00
# Cantidad de dias 180 days 00:00:00

# %% [markdown]
# ### Se crea un Data Frame para realizar la serie de tiempo

# %%
valor = {
'fecha' : union['fecha'],
'cantidad': union['cantidad']
}
df_valor = pd.DataFrame(valor)
# se cambie el index del DataFrame
df_valor = df_valor.set_index('fecha')
df_valor.head()
# Out:
#             cantidad
# fecha
# 2020-11-01      71.0
# 2020-11-01      51.0
# 2020-11-01      10.0
# 2020-11-01      15.0
# 2020-11-01      37.0

# %% [markdown]
# #### Se define la serie de tiempo en la cual vamos a trabajar, en este caso de lunes a domingo

# %%
# resample y agregacion por mes
valor_resample_mes = df_valor.cantidad.resample('BM').count()
# asignar día de la semana
df_resample = pd.concat([valor_resample_mes], axis=1)
df_resample['dayofweek'] = df_resample.index.dayofweek # 0 es lunes
# lunes a domingo
df_lun_to_dom = df_resample[df_resample.dayofweek.isin([0,1,2,3,4,5,6])].cantidad



df_lun_to_dom.plot()
# Out:
# <AxesSubplot:xlabel='fecha'>

# %%
# Librerias
from datetime import datetime, timedelta
from matplotlib import dates as mpl_dates

# %%
print("Fecha inicial", union['fecha'].min())
print("Fecha final", union['fecha'].max())
print("Cantidad de dias", union['fecha'].max() - union['fecha'].min() )
# Out:
# Fecha inicial 2020-11-01 00:00:00
# Fecha final 2021-04-30 00:00:00
# Cantidad de dias 180 days 00:00:00

# %%
# Se crea un Data Frame para realizar la serie de tiempo
valor = {
    'fecha' : union['fecha'],
    'cantidad': union['cantidad']
}
df_cantidad = pd.DataFrame(valor)
# se cambie el index del DataFrame
df_cantidad = df_cantidad.set_index('fecha')
df_cantidad.head()
# Out:
#             cantidad
# fecha
# 2020-11-01      71.0
# 2020-11-01      51.0
# 2020-11-01      10.0
# 2020-11-01      15.0
# 2020-11-01      37.0

# %%
df_cantidad.plot()
# Out:
# <AxesSubplot:xlabel='fecha'>

# %% [markdown]
# #### Analizis de series de tiempo

# %%
df_union = pd.pivot_table(union,
               index=['pais_x'],
               columns=['fecha'],
               values=['cantidad'],
               aggfunc='count',
               fill_value=0,
               margins=False,
               margins_name='Total')

# %%
df_union
# Out:
#             cantidad                                                         \
# fecha     2020-11-01 2020-11-02 2020-11-03 2020-11-04 2020-11-05 2020-11-06
# pais_x
# ARGENTINA         50         48         46         52         56         48
# CHILE             16         17         18         16         20         15
# COLOMBIA           4          5          6          5          6          5
# ECUADOR            6          6          7          7          8          6
# PERU               5          5          5          4          4          5
# URUGUAY           16         14         20         23         22         21
#
#                                                        ...             \
# fecha     2020-11-07 2020-11-08 2020-11-09 2020-11-10  ... 2021-04-21
# pais_x                                                 ...
# ARGENTINA         46         46         49         45  ...         46
# CHILE             17         20         15         16  ...         37
# COLOMBIA           5          5          5          6  ...         42
# ECUADOR            4          6          7          9  ...         11
# PERU               4          5          5          4  ...         18
# URUGUAY           21         14         31         21  ...         18
#
#                                                                              \
# fecha     2021-04-22 2021-04-23 2021-04-24 2021-04-25 2021-04-26 2021-04-27
# pais_x
# ARGENTINA         47         45         47         48         46         49
# CHILE             33         35         42         42         38         40
# COLOMBIA          43         44         46         43         41         45
# ECUADOR           12         11         10         10         10         11
# PERU              17         20         10         10         10         12
# URUGUAY           23         23         21         21         22         20
#
#
# fecha     2021-04-28 2021-04-29 2021-04-30
# pais_x
# ARGENTINA         46         47         46
# CHILE             42         36         35
# COLOMBIA          47         45         45
# ECUADOR           12         11         12
# PERU              11         17         18
# URUGUAY           22         17         20
#
# [6 rows x 181 columns]

# %% [markdown]
# #### Se suman las filas

# %%
# se cambia el nombre del index
df_union = df_union.rename_axis(['pais_x'])
df_union = df_union.groupby('pais_x').agg('sum')
df_union
# Out:
#             cantidad                                                         \
# fecha     2020-11-01 2020-11-02 2020-11-03 2020-11-04 2020-11-05 2020-11-06
# pais_x
# ARGENTINA         50         48         46         52         56         48
# CHILE             16         17         18         16         20         15
# COLOMBIA           4          5          6          5          6          5
# ECUADOR            6          6          7          7          8          6
# PERU               5          5          5          4          4          5
# URUGUAY           16         14         20         23         22         21
#
#                                                        ...             \
# fecha     2020-11-07 2020-11-08 2020-11-09 2020-11-10  ... 2021-04-21
# pais_x                                                 ...
# ARGENTINA         46         46         49         45  ...         46
# CHILE             17         20         15         16  ...         37
# COLOMBIA           5          5          5          6  ...         42
# ECUADOR            4          6          7          9  ...         11
# PERU               4          5          5          4  ...         18
# URUGUAY           21         14         31         21  ...         18
#
#                                                                              \
# fecha     2021-04-22 2021-04-23 2021-04-24 2021-04-25 2021-04-26 2021-04-27
# pais_x
# ARGENTINA         47         45         47         48         46         49
# CHILE             33         35         42         42         38         40
# COLOMBIA          43         44         46         43         41         45
# ECUADOR           12         11         10         10         10         11
# PERU              17         20         10         10         10         12
# URUGUAY           23         23         21         21         22         20
#
#
# fecha     2021-04-28 2021-04-29 2021-04-30
# pais_x
# ARGENTINA         46         47         46
# CHILE             42         36         35
# COLOMBIA          47         45         45
# ECUADOR           12         11         12
# PERU              11         17         18
# URUGUAY           22         17         20
#
# [6 rows x 181 columns]

# %% [markdown]
# #### Se toman los paises como columnas

# %%
df_union = df_union.T
df_union
# Out:
# pais_x               ARGENTINA  CHILE  COLOMBIA  ECUADOR  PERU  URUGUAY
#          fecha
# cantidad 2020-11-01         50     16         4        6     5       16
#          2020-11-02         48     17         5        6     5       14
#          2020-11-03         46     18         6        7     5       20
#          2020-11-04         52     16         5        7     4       23
#          2020-11-05         56     20         6        8     4       22
# ...                        ...    ...       ...      ...   ...      ...
#          2021-04-26         46     38        41       10    10       22
#          2021-04-27         49     40        45       11    12       20
#          2021-04-28         46     42        47       12    11       22
#          2021-04-29         47     36        45       11    17       17
#          2021-04-30         46     35        45       12    18       20
#
# [181 rows x 6 columns]

# %% [markdown]
# ### Exportamos el Dataframe con los datos

# %%
df_union.to_excel("Errores_pais.xlsx")

# %%
# Importamos la data
df_Errores_pais = pd.read_excel("Errores_pais.xlsx")
df_Errores_pais.rename({"Unnamed: 0":"columna01"}, axis="columns", inplace=True)
# Eliminamos el campo vacio creado por el multi index
df_Errores_pais.drop(["columna01"], axis=1, inplace=True)
df_Errores_pais.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181 entries, 0 to 180
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   fecha      181 non-null    datetime64[ns]
#  1   ARGENTINA  181 non-null    int64
#  2   CHILE      181 non-null    int64
#  3   COLOMBIA   181 non-null    int64
#  4   ECUADOR    181 non-null    int64
#  5   PERU       181 non-null    int64
#  6   URUGUAY    181 non-null    int64
# dtypes: datetime64[ns](1), int64(6)
# memory usage: 10.0 KB

# %%
# ¿Hay datos nulos?
print(df_Errores_pais.isnull().sum())
# Out:
# fecha        0
# ARGENTINA    0
# CHILE        0
# COLOMBIA     0
# ECUADOR      0
# PERU         0
# URUGUAY      0
# dtype: int64

# %% [markdown]
# #### Para usar la función de análisis de series de tiempo, necesitamos crear un DateTime como columna de índice

# %%
df_Errores_pais['fecha'] = pd.to_datetime(df_Errores_pais['fecha'])
# Set the column 'Date' as index (skip if already done)
df_Errores_pais = df_Errores_pais.set_index('fecha')
# Specify datetime frequency
df_Errores_pais = df_Errores_pais.asfreq('D')
df_Errores_pais[df_Errores_pais.index.day == 15]
# Out:
#             ARGENTINA  CHILE  COLOMBIA  ECUADOR  PERU  URUGUAY
# fecha
# 2020-11-15         47     20         5        5     5       22
# 2020-12-15         51      8        28        6     4       20
# 2021-01-15         43     18        37       10    20       17
# 2021-02-15         51     18        40        9    19       24
# 2021-03-15         54     33        40       13    20       22
# 2021-04-15         45     32        42       12    17       15

# %% [markdown]
# #### Confirmamos si hay datos nulos

# %%
# ¿Hay datos nulos?
print(df_Errores_pais.isnull().sum())
# Out:
# ARGENTINA    0
# CHILE        0
# COLOMBIA     0
# ECUADOR      0
# PERU         0
# URUGUAY      0
# dtype: int64

# %% [markdown]
# #### Se seleccionan colombia y argentina para poder hacer la estimacion con ellos y se crea el dataframe llamado Errores_pais_colombia_argentina

# %%
df_Errores_pais = df_Errores_pais.sort_values(by=df_Errores_pais.index.values[-1], axis=1,ascending=False)
df_Errores_pais_colombia_argentina= df_Errores_pais.iloc[:,0:2]

# %%
print(df_Errores_pais)
# Out:
#             ARGENTINA  COLOMBIA  CHILE  URUGUAY  PERU  ECUADOR
# fecha
# 2020-11-01         50         4     16       16     5        6
# 2020-11-02         48         5     17       14     5        6
# 2020-11-03         46         6     18       20     5        7
# 2020-11-04         52         5     16       23     4        7
# 2020-11-05         56         6     20       22     4        8
# ...               ...       ...    ...      ...   ...      ...
# 2021-04-26         46        41     38       22    10       10
# 2021-04-27         49        45     40       20    12       11
# 2021-04-28         46        47     42       22    11       12
# 2021-04-29         47        45     36       17    17       11
# 2021-04-30         46        45     35       20    18       12
#
# [181 rows x 6 columns]

# %% [markdown]
# #### Se saca la media remuestral por la cantidad en cada pais por semana

# %%
#Resample the dataframe
df_Errores_pais.resample('W').mean()
#You can plot the chart by adding .plot()
df_Errores_pais.resample('W').mean().plot()
# Out:
# <AxesSubplot:xlabel='fecha'>

# %%
df_Errores_pais.resample('W').mean().plot(marker="v",figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='fecha'>

# %% [markdown]
# #### Ahora, encontremos un crecimiento porcentual mensual

# %%
df_Errores_pais.resample('M').mean().pct_change()
# Out:
#             ARGENTINA  COLOMBIA     CHILE   URUGUAY      PERU   ECUADOR
# fecha
# 2020-11-30        NaN       NaN       NaN       NaN       NaN       NaN
# 2020-12-31  -0.028802  3.832506 -0.190427 -0.255699 -0.111111 -0.158266
# 2021-01-31  -0.045552  0.319641  0.331620  0.210953  2.870968  0.293413
# 2021-02-28   0.230159  0.193302  0.092181  0.162778  0.273214  0.665840
# 2021-03-31  -0.057372  0.040177  0.919576 -0.092453  0.014493  0.042184
# 2021-04-30  -0.067674  0.032524  0.054266 -0.028995 -0.156667 -0.107200

# %%
df_Errores_pais.resample('M').mean().pct_change().iloc[2:].plot(marker="v",figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='fecha'>

# %%
df_Errores_pais.rolling('D').mean().plot(marker="v",figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='fecha'>

# %% [markdown]
# ### Análisis en las tendencias por serie de tiempo
# #### Predicciones

# %%
import pprint
# %matplotlib inline

# %%
# datos = pd.DataFrame
datos = pd.DataFrame(datos)
datos.columns
# Preparación de los datos
dicc = {
    'fecha' : datos['fecha'],
    'valor': datos['cantidad']
    
}
df_prediccion = pd.DataFrame(dicc)
# elimina las filas que tengas fecha vacia (420)
df_prediccion = df_prediccion.dropna()
df_prediccion['fecha'] = pd.to_datetime(df_prediccion['fecha'], errors='coerce')
#df_prediccion = df_prediccion.set_index('FECHA')
df_prediccion.head()
# Out:
#        fecha  valor
# 0 2020-11-01   71.0
# 1 2020-11-01   51.0
# 2 2020-11-01   10.0
# 3 2020-11-01   15.0
# 4 2020-11-01   37.0

# %%
dataset = df_prediccion

dataset['Month'] = df_prediccion['fecha'].dt.month
dataset['Year'] = df_prediccion['fecha'].dt.year
dataset['Date'] = df_prediccion['fecha'].dt.date
dataset['Time'] = df_prediccion['fecha'].dt.time
dataset['Week'] = df_prediccion['fecha'].dt.week
dataset['Day'] = df_prediccion['fecha'].dt.day_name()
dataset = df_prediccion.set_index('fecha')
dataset.index = pd.to_datetime(dataset.index)
dataset.head()
# Out:
# <ipython-input-283-b9e39c3ced29>:7: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   dataset['Week'] = df_prediccion['fecha'].dt.week
#             valor  Month  Year        Date      Time  Week     Day
# fecha
# 2020-11-01   71.0     11  2020  2020-11-01  00:00:00    44  Sunday
# 2020-11-01   51.0     11  2020  2020-11-01  00:00:00    44  Sunday
# 2020-11-01   10.0     11  2020  2020-11-01  00:00:00    44  Sunday
# 2020-11-01   15.0     11  2020  2020-11-01  00:00:00    44  Sunday
# 2020-11-01   37.0     11  2020  2020-11-01  00:00:00    44  Sunday

# %% [markdown]
# #### Posibles pruebas

# %%
df_prediccion.head(1)
# Out:
#        fecha  valor  Month  Year        Date      Time  Week     Day
# 0 2020-11-01   71.0     11  2020  2020-11-01  00:00:00    44  Sunday

# %%
df_prediccion.Year.unique()
# Out:
# array([2020, 2021], dtype=int64)

# %%
from matplotlib import style 

fig = plt.figure()
axl = plt.subplot2grid((1,1), (0,0))

style.use('ggplot')

sns.lineplot(x=dataset['Year'], y=dataset['valor'], data=df_prediccion)

plt.title('errores obtenidos')
plt.xlabel('Date')
plt.ylabel('errores en unidades')
plt.grid(True)
plt.legend()

for label in axl.xaxis.get_ticklabels():
    label.set_rotation(90)

plt.title('errores obtenidos por año')
# Out:
# No handles with labels found to put in legend.
# Text(0.5, 1.0, 'errores obtenidos por año')

# %% [markdown]
# #### Reenzamble de datos

# %%
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler, MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dense,LSTM

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)

sns.lineplot(x=dataset["Date"], y=dataset["valor"], data=datos)
plt.title("Cantidad errores vs Tiempo")
plt.xlabel("Date")
plt.grid(True, alpha=1)
plt.legend()

for label in ax1.xaxis.get_ticklabels():
    label.set_rotation(90)
# Out:
# No handles with labels found to put in legend.

# %%
NewDataSet = dataset.resample('D').mean()

# %%
print('Dataset antiguo', dataset.shape)
print('Dataset nuevo', NewDataSet.shape)
# Out:
# Dataset antiguo (25889, 7)
# Dataset nuevo (181, 4)

# %%
# Datos de prueba
TestData = NewDataSet.tail(100)
Training_Set = NewDataSet.iloc[:,0:1]
Training_Set = Training_Set[:-60]

# %%
print('Forma de conjunto de entrenamiento', Training_Set.shape)
print('forma de conjunto de prueba', TestData.shape)
# Out:
# Forma de conjunto de entrenamiento (121, 1)
# forma de conjunto de prueba (100, 4)

# %%
Training_Set = Training_Set.values
sc = MinMaxScaler(feature_range=(0, 1))
Train = sc.fit_transform(Training_Set)

# %%
# Entrenamiento
X_Train = []
Y_Train = []

# Rango de valores
for i in range(60, Train.shape[0]):
    
    X_Train.append(Train[i-60:i])
    
    Y_Train.append(Train[i])
    

# Convierte a Numpy Array
X_Train = np.array(X_Train)
Y_Train = np.array(Y_Train)
    
print(X_Train.shape)
print(Y_Train.shape)
# Out:
# (61, 60, 1)
# (61, 1)

# %%
X_Train = np.reshape(X_Train, newshape=(X_Train.shape[0], X_Train.shape[1], 1))
X_Train.shape
# Out:
# (61, 60, 1)

# %% [markdown]
# ### Modelo LSTM

# %%
regressor = Sequential()

# Adiciona el primer elemento
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_Train.shape[1], 1)))
regressor.add(Dropout(0.2))

# Adiciona el segundo elemento
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# Adiciona el tercero elemento
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# Adiciona el cuarto elemento
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))

# Salida
regressor.add(Dense(units = 1))

# Compilando RNN
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
regressor.fit(X_Train, Y_Train, epochs=50, batch_size=128)
# Out:
# Epoch 1/50
# 1/1 [==============================] - 0s 0s/step - loss: 0.1834
# Epoch 2/50
# 1/1 [==============================] - 0s 998us/step - loss: 0.1484
# Epoch 3/50
# 1/1 [==============================] - 0s 998us/step - loss: 0.1039
# Epoch 4/50
# 1/1 [==============================] - 0s 998us/step - loss: 0.0653
# Epoch 5/50
# 1/1 [==============================] - 0s 997us/step - loss: 0.0302
# Epoch 6/50
# 1/1 [==============================] - 0s 998us/step - loss: 0.0396
# Epoch 7/50
# 1/1 [==============================] - 0s 998us/step - loss: 0.0519
# Epoch 8/50
# 1/1 [==============================] - 0s 0s/step - loss: 0.0414
# Epoch 9/50
# 1/1 [==============================] - 0s 0s/step - loss: 0.0278
# Epoch 10/50
# 1/1 [==============================] - 0s 997us/step - loss: 0.0265
# Epoch 11/50
# 1/1 [==============================] - 0s 998us/step - loss: 0.0293
# Epoch 12/50
# 1/1 [==============================] - 0s 0s/step - loss: 0.0347
# Epoch 13/50
# 1/1 [==============================] - 0s 997us/step - loss: 0.0341
# Epoch 14/50
# 1/1 [==============================] - 0s 998us/step - loss: 0.0348
# Epoch 15/50
# 1/1 [==============================] - 0s 998us/step - loss: 0.0320
# Epoch 16/50
# 1/1 [==============================] - 0s 997us/step - loss: 0.0286
# Epoch 17/50
# 1/1 [==============================] - 0s 998us/step - loss: 0.0254
# Epoch 18/50
# 1/1 [==============================] - 0s 998us/step - loss: 0.0240
# Epoch 19/50
# 1/1 [==============================] - 0s 0s/step - loss: 0.0267
# Epoch 20/50
# 1/1 [==============================] - 0s 998us/step - loss: 0.0232
# Epoch 21/50
# 1/1 [==============================] - 0s 998us/step - loss: 0.0282
# Epoch 22/50
# 1/1 [==============================] - 0s 0s/step - loss: 0.0307
# Epoch 23/50
# 1/1 [==============================] - 0s 998us/step - loss: 0.0321
# Epoch 24/50
# 1/1 [==============================] - 0s 998us/step - loss: 0.0251
# Epoch 25/50
# 1/1 [==============================] - 0s 0s/step - loss: 0.0243
# Epoch 26/50
# 1/1 [==============================] - 0s 0s/step - loss: 0.0249
# Epoch 27/50
# 1/1 [==============================] - 0s 997us/step - loss: 0.0250
# Epoch 28/50
# 1/1 [==============================] - 0s 0s/step - loss: 0.0286
# Epoch 29/50
# 1/1 [==============================] - 0s 997us/step - loss: 0.0231
# Epoch 30/50
# 1/1 [==============================] - 0s 996us/step - loss: 0.0265
# Epoch 31/50
# 1/1 [==============================] - 0s 997us/step - loss: 0.0243
# Epoch 32/50
# 1/1 [==============================] - 0s 998us/step - loss: 0.0239
# Epoch 33/50
# 1/1 [==============================] - 0s 997us/step - loss: 0.0234
# Epoch 34/50
# 1/1 [==============================] - 0s 0s/step - loss: 0.0234
# Epoch 35/50
# 1/1 [==============================] - 0s 0s/step - loss: 0.0251
# Epoch 36/50
# 1/1 [==============================] - 0s 998us/step - loss: 0.0235
# Epoch 37/50
# 1/1 [==============================] - 0s 996us/step - loss: 0.0243
# Epoch 38/50
# 1/1 [==============================] - 0s 0s/step - loss: 0.0239
# Epoch 39/50
# 1/1 [==============================] - 0s 0s/step - loss: 0.0242
# Epoch 40/50
# 1/1 [==============================] - 0s 998us/step - loss: 0.0220
# Epoch 41/50
# 1/1 [==============================] - 0s 998us/step - loss: 0.0221
# Epoch 42/50
# 1/1 [==============================] - 0s 0s/step - loss: 0.0226
# Epoch 43/50
# 1/1 [==============================] - 0s 0s/step - loss: 0.0242
# Epoch 44/50
# 1/1 [==============================] - 0s 997us/step - loss: 0.0211
# Epoch 45/50
# 1/1 [==============================] - 0s 0s/step - loss: 0.0291
# Epoch 46/50
# 1/1 [==============================] - 0s 998us/step - loss: 0.0246
# Epoch 47/50
# 1/1 [==============================] - 0s 998us/step - loss: 0.0219
# Epoch 48/50
# 1/1 [==============================] - 0s 998us/step - loss: 0.0204
# Epoch 49/50
# 1/1 [==============================] - 0s 998us/step - loss: 0.0236
# Epoch 50/50
# 1/1 [==============================] - 0s 997us/step - loss: 0.0236

# %% [markdown]
# ### Testing de los datos

# %%
TestData.head(22)
# Out:
#                  valor  Month  Year  Week
# fecha
# 2021-01-21   77.519531      1  2021     3
# 2021-01-22   72.957265      1  2021     3
# 2021-01-23   78.724138      1  2021     3
# 2021-01-24   56.248055      1  2021     3
# 2021-01-25   81.842329      1  2021     4
# 2021-01-26   83.465517      1  2021     4
# 2021-01-27   91.518391      1  2021     4
# 2021-01-28   90.411515      1  2021     4
# 2021-01-29   91.823077      1  2021     4
# 2021-01-30   87.859531      1  2021     4
# 2021-01-31   77.223414      1  2021     4
# 2021-02-01  111.745151      2  2021     5
# 2021-02-02  105.086705      2  2021     5
# 2021-02-03   95.743324      2  2021     5
# 2021-02-04   85.398278      2  2021     5
# 2021-02-05   81.653179      2  2021     5
# 2021-02-06   82.638211      2  2021     5
# 2021-02-07   65.226911      2  2021     5
# 2021-02-08   90.445714      2  2021     6
# 2021-02-09   91.332044      2  2021     6
# 2021-02-10   95.886905      2  2021     6
# 2021-02-11   90.128779      2  2021     6

# %%
# Figura del test
TestData.shape
# Out:
# (100, 4)

# %%
# Figura datos
NewDataSet.shape
# Out:
# (181, 4)

# %%
#Dataframe con datos de test reales
Df_Total = pd.concat((NewDataSet[["valor"]], TestData[["valor"]]), axis=0)

# %%
#Figura del dataset
Df_Total.shape
# Out:
# (281, 1)

# %%
#Entradas
inputs=Df_Total[len(Df_Total)- len(TestData)-60:].values
inputs.shape
# Out:
# (160, 1)

# %%
#Entrenamiento
inputs = Df_Total[len(Df_Total) - len(TestData) -60:].values

inputs = inputs.reshape(-1,1)

inputs = sc.transform(inputs)

X_test = []
for i in range(60, 160):
    X_test.append(inputs[i-60:i])
    
X_test = np.array(X_test)

X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

erroresesperados = regressor.predict(X_test)

erroresesperados = sc.inverse_transform(erroresesperados)

# %%
#Entradas
Truemodelo = TestData["valor"].to_list()
Prediccionmodelo = erroresesperados
fecha = TestData.index.to_list()

# %%
Prediccionfinal = pd.DataFrame(data={
    "fecha":fecha,
    "verdad modelo": Truemodelo,
    "prediccion":[x[0]for x in Prediccionmodelo ]
})

# %%
#Resultado final
Prediccionfinal
# Out:
#         fecha  verdad modelo  prediccion
# 0  2021-01-21      77.519531   75.320602
# 1  2021-01-22      72.957265   75.069626
# 2  2021-01-23      78.724138   74.871826
# 3  2021-01-24      56.248055   74.755478
# 4  2021-01-25      81.842329   74.713531
# ..        ...            ...         ...
# 95 2021-04-26      52.174525   76.590073
# 96 2021-04-27      56.331083   76.362221
# 97 2021-04-28      55.193696   76.117584
# 98 2021-04-29      51.822532   75.861549
# 99 2021-04-30      53.421243   75.595207
#
# [100 rows x 3 columns]

# %%
Truemodelo = TestData["valor"].to_list()
Prediccionmodelo = [x[0]for x in Prediccionmodelo]
fecha = TestData.index.to_list()

# %%
fig = plt.figure(figsize=(20,10))

ax1 = fig.add_subplot(111)

x = fecha 
y = Truemodelo

y1 = Prediccionmodelo

plt.plot(x,y, color="green")
plt.plot(x,y1, color="red")

plt.gcf().autofmt_xdate()
plt.xlabel('fecha')
plt.ylabel('errores')
plt.title("Prediccion de los errores a futuro")
plt.legend()
# Out:
# No handles with labels found to put in legend.
